# %% [markdown]
# ### Задание 3

# %% [markdown]
# ##### 1. Задание (в программе)
# Нарисуйте график функции:
# y(x) = k∙cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-10, 10, 0.1)

# %%
for _ in range(3):
    k = 80 * random.random()
    a = (20 - 2.5) * random.random() + 2.5
    b = (5 + 1) * random.random() - 1
    y = k * np.cos(x - a) + b
    plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 2. Задание
# ##### Докажите, что при ортогональном преобразовании сохраняется расстояние между точками.

# %% [markdown]
# Приведем док-во на плоскости, в многомерном прострастве все аналогично. Пусть L1 - расстояние м/у точкам в координатах x, y, а L2 - в координатах x', y', тогда:
#
# $L1^2 = (x1 - x2)^2 + (y1 - y2)^2;$
# $L2^2 = (x1' - x2')^2 + (y1' - y2')^2;$
# $x' = a11*x + a12*y + a13;$
# $y' = a21*x + a22*y + a23;$
#
# Подставляем преобразование координат в уравнение, раскрываем скобки, комбинируем переменные и выносим их за скобки
# $L2^2 = (a11*x1 + a12*y1 + a13 - a11*x2 - a12*y2 - a13)^2 + (a21*x1 + a22*y1 + a23 - a21*x2 - a22*y2 - a23)^2;$
# $L2^2 = (a11*(x1-x2) + a12*(y1-y2))^2 + (a21*(x1-x2) + a22*(y1-y2))^2;$
# $L2^2 = a11^2*(x1-x2)^2 + 2*a11*a12(x1-x2)*(y1-y2) + a12^2*(y1-y2)^2 + a21^2*(x1-x2)^2 + 2*a21*a22(x1-x2)*(y1-y2) + a22^2*(y1-y2)^2;$
# $L2^2 = (a11^2 + a21^2)*(x1 - x2)^2 + (a12^2 + a22^2)*(y1 - y2)^2 + 2*(x1-x2)*(y1-y2)*(a11*a12+a21*a22);$
#
# По свойству ортогональных преобразований:
# $a11^2 + a21^2 = 1;$
# $a12^2 + a22^2 = 1;$
# $a11*a12 + a21*a22 = 0;$
#
# Следовательно $L2^2 = (x1 - x2)^2 + (y1 - y2)^2 = L1^2$ (чтд)

# %% [markdown]
# ### 3. Задание (в программе)
# 1. Напишите код, который будет переводить полярные координаты в декартовы.
# 2. Напишите код, который будет рисовать график окружности в полярных координатах.
# 3. Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %%
def polar_to_cartesian(rho, theta):
    x = rho * np.cos(theta)
    y = rho * np.sin(theta)
    return (x, y)

# %%
r = 5
x = np.linspace(-5, 5, 101)
y = np.sqrt(r**2 - x**2)
plt.polar(x, y)
plt.show()

# %%
x = np.linspace(-5, 5, 101)
k = 100 * random.random()
b = 100 * random.random()
y = k * x + b
plt.figure(figsize=(4,4))
plt.polar(x, y)
plt.show()

# %% [markdown]
# ### 4. Задание (в программе)
# Решите систему уравнений:
# y = x2 – 1
# exp(x) + x∙(1 – y) = 1

# %%
import warnings
warnings.filterwarnings("ignore") 
from scipy.optimize import fsolve

# %%
x = np.linspace(-5, 5, 501)
plt.plot(x, x**2 - 1)
plt.plot(x, (np.exp(x) - 1)/x + 1)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
def equations(p):
    x, y = p
    return (x**2 - 1 - y, np.exp(x) + x*(1 - y) - 1)

x1, y1 = fsolve(equations, (-2, 5))
x2, y2 = fsolve(equations, (2, 5))
x3, y3 = fsolve(equations, (4, 15))
print(f'Решение 1: [{x1}, {y1}];\n'
      f'Решение 2: [{x2}, {y2}];\n'
      f'Решение 3: [{x3}, {y3}].')
# Out:
# Решение 1: [-1.5818353528958997, 1.5022030836712943];
# Решение 2: [2.6181455730830665, 5.854686241850253];
# Решение 3: [4.200105841149689, 16.640889076862805].
